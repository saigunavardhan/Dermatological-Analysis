# %%
#Computer Vision Dermatological Analysis
#Sathi Vaigarai, Sai Gunavardhan, Varun Teja K

import numpy as np
import glob
# %matplotlib widget
# %matplotlib inline
import matplotlib.pyplot as plt
import skimage.io
import skimage.color
import skimage.filters


# load the image
image = skimage.io.imread("img1.jpg")

fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

# %%
gray_image = skimage.color.rgb2gray(image)

# blur the image to denoise
blurred_image = skimage.filters.gaussian(gray_image, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")
plt.show()

# %%
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))

fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0, 1.0)
# Out:
# (0.0, 1.0)

# %%
t = 0.5
binary_mask = blurred_image < t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap="gray")
plt.show()

# %%
selection = image.copy()
selection[~binary_mask] = 0

fig, ax = plt.subplots()
plt.imshow(selection)
plt.show()

# %%
import numpy as np
import glob
# %matplotlib widget
# %matplotlib inline
import matplotlib.pyplot as plt
import skimage.io
import skimage.color
import skimage.filters


# load the image
image = skimage.io.imread("img2.jpg")

fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

# %%
gray_image = skimage.color.rgb2gray(image)

# blur the image to denoise
blurred_image = skimage.filters.gaussian(gray_image, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")
plt.show()

# %%
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))

fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0, 1.0)
# Out:
# (0.0, 1.0)

# %%
t = 0.5
binary_mask = blurred_image < t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap="gray")
plt.show()

# %%
selection = image.copy()
selection[~binary_mask] = 0

fig, ax = plt.subplots()
plt.imshow(selection)
plt.savefig('myplot2.png')
plt.show()

# %%
import cv2
import numpy as np
img = cv2.imread('my_plot.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
cv2.imshow("Mask", thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
area1 = cv2.countNonZero(thresh)
print(area1)
# Out:
# 60029

# %%
import cv2
import numpy as np
img = cv2.imread('myplot2.png')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
cv2.imshow("Mask", thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
area2 = cv2.countNonZero(thresh)
print(area2)
# Out:
# 60422

# %%
a1 = int(area1)
a2 = int(area2)
if a2>a1:
    i = (a2-a1)*100/a1
    print("There is an increase of ", i)
# Out:
# There is an increase of  0.6546835696080228

# %%
import numpy as np
import glob
# %matplotlib widget
# %matplotlib inline
import matplotlib.pyplot as plt
import skimage.io
import skimage.color
import skimage.filters


# load the image
image = skimage.io.imread("img3.jpg")

fig, ax = plt.subplots()
plt.imshow(image)
plt.show()

# %%
gray_image = skimage.color.rgb2gray(image)

# blur the image to denoise
blurred_image = skimage.filters.gaussian(gray_image, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")
plt.show()

# %%
histogram, bin_edges = np.histogram(blurred_image, bins=256, range=(0.0, 1.0))

fig, ax = plt.subplots()
plt.plot(bin_edges[0:-1], histogram)
plt.title("Grayscale Histogram")
plt.xlabel("grayscale value")
plt.ylabel("pixels")
plt.xlim(0, 1.0)
# Out:
# (0.0, 1.0)

# %%
t = 0.5
binary_mask = blurred_image < t

fig, ax = plt.subplots()
plt.imshow(binary_mask, cmap="gray")
plt.show()

# %%
selection = image.copy()
selection[~binary_mask] = 0

fig, ax = plt.subplots()
plt.imshow(selection)
plt.savefig('myplot2.png')
plt.show()

# %%
gray = cv2.cvtColor(selection,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(gray,0,255,cv2.THRESH_BINARY)
cv2.imshow("Mask", thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
area1 = cv2.countNonZero(thresh)
print(area1)
# Out:
# 28442
